# %% [markdown]
# <style>
# :root {
#   --bg:       #0d1b2a;
#   --bg2:      #1a2a3a;
#   --bg3:      #0a1628;
#   --accent:   #1b91ff;
#   --orange:   #e07b39;
#   --green:    #2fca72;
#   --gold:     #f0c040;
#   --text:     #c8d8e8;
#   --text2:    #8ab4d4;
#   --border:   #1b3a5c;
#   --code-bg:  #1e2d3d;
#   --code-fg:  #7fdbca;
#   --red:      #e05555;
# }
# body, .jp-RenderedHTMLCommon {
#   background: var(--bg) !important;
#   color: var(--text) !important;
#   font-family: 'Segoe UI', Arial, sans-serif !important;
# }
# h1,h2,h3,h4 { color: #ffffff !important; }
# h1 { border-bottom: 2px solid var(--accent) !important; padding-bottom: 8px !important; }
# h2 { color: var(--accent) !important; }
# h3 { color: var(--text2) !important; }
# a  { color: var(--accent) !important; }
# code {
#   background: var(--code-bg) !important;
#   color: var(--code-fg) !important;
#   padding: 2px 6px !important;
#   border-radius: 4px !important;
# }
# pre code { padding: 0 !important; }
# pre {
#   background: var(--code-bg) !important;
#   border-left: 3px solid var(--accent) !important;
#   border-radius: 6px !important;
#   padding: 14px 18px !important;
# }
# table { border-collapse: collapse !important; width: 100% !important; }
# th {
#   background: var(--bg3) !important;
#   color: var(--accent) !important;
#   border: 1px solid var(--border) !important;
#   padding: 8px 12px !important;
# }
# td {
#   border: 1px solid var(--border) !important;
#   padding: 8px 12px !important;
#   color: var(--text) !important;
# }
# tr:nth-child(even) td { background: var(--bg2) !important; }
# blockquote {
#   border-left: 4px solid var(--gold) !important;
#   background: #1a2a1a !important;
#   padding: 10px 16px !important;
#   border-radius: 0 8px 8px 0 !important;
#   color: var(--text) !important;
# }
# </style>

# %% [markdown]
# <style>
# :root {
#   --bg:       #0d1b2a;
#   --bg2:      #1a2a3a;
#   --bg3:      #0a1628;
#   --accent:   #1b91ff;
#   --orange:   #e07b39;
#   --green:    #2fca72;
#   --gold:     #f0c040;
#   --text:     #c8d8e8;
#   --text2:    #8ab4d4;
#   --border:   #1b3a5c;
#   --code-bg:  #1e2d3d;
#   --code-fg:  #7fdbca;
#   --red:      #e05555;
# }
# body, .jp-RenderedHTMLCommon {
#   background: var(--bg) !important;
#   color: var(--text) !important;
#   font-family: 'Segoe UI', Arial, sans-serif !important;
# }
# h1,h2,h3,h4 { color: #ffffff !important; }
# h1 { border-bottom: 2px solid var(--accent) !important; padding-bottom: 8px !important; }
# h2 { color: var(--accent) !important; }
# h3 { color: var(--text2) !important; }
# a  { color: var(--accent) !important; }
# code {
#   background: var(--code-bg) !important;
#   color: var(--code-fg) !important;
#   padding: 2px 6px !important;
#   border-radius: 4px !important;
# }
# pre code { padding: 0 !important; }
# pre {
#   background: var(--code-bg) !important;
#   border-left: 3px solid var(--accent) !important;
#   border-radius: 6px !important;
#   padding: 14px 18px !important;
# }
# table { border-collapse: collapse !important; width: 100% !important; }
# th {
#   background: var(--bg3) !important;
#   color: var(--accent) !important;
#   border: 1px solid var(--border) !important;
#   padding: 8px 12px !important;
# }
# td {
#   border: 1px solid var(--border) !important;
#   padding: 8px 12px !important;
#   color: var(--text) !important;
# }
# tr:nth-child(even) td { background: var(--bg2) !important; }
# blockquote {
#   border-left: 4px solid var(--gold) !important;
#   background: #1a2a1a !important;
#   padding: 10px 16px !important;
#   border-radius: 0 8px 8px 0 !important;
#   color: var(--text) !important;
# }
# </style>
# <div style="background:linear-gradient(135deg,#1a2332 0%,#0d1b2a 100%);border-radius:16px;padding:36px;margin-bottom:12px;">
#   <div style="display:flex;align-items:center;gap:18px;margin-bottom:16px;">
#     <div style="background:#1b91ff;color:#fff;font-size:36px;font-weight:900;border-radius:12px;padding:8px 20px;">9</div>
#     <div>
#       <div style="color:#8ab4d4;font-size:12px;font-weight:600;letter-spacing:3px;text-transform:uppercase;">ЕГЭ по информатике</div>
#       <div style="color:#ffffff;font-size:24px;font-weight:800;">Обработка числовой информации</div>
#
#     </div>
#   </div>
#   <div style="display:flex;gap:8px;flex-wrap:wrap;"><span style="background:#1b3a5c;color:#7ec8e3;font-size:12px;padding:4px 14px;border-radius:20px;font-weight:600;">Python</span> <span style="background:#1b3a5c;color:#7ec8e3;font-size:12px;padding:4px 14px;border-radius:20px;font-weight:600;">Электронные таблицы</span> </div>
# </div>
#
# <div style="background:#0a1628;border:1px solid #1b3a5c;border-radius:8px;padding:10px 18px;margin-bottom:16px;display:inline-block;">
# <a href="../../README.md" style="color:#1b91ff;text-decoration:none;font-weight:600;">← Назад ко всем заданиям</a>
# </div>

# %% [markdown]
# # Решение задачи №9 из ЕГЭ по информатике
#
# ## Условие задачи
#
# Откройте файл электронной таблицы, содержащей в каждой строке пять натуральных чисел. Определите количество строк таблицы, для чисел которых выполнены оба условия:
#
# 1. В строке все числа различны
# 2. Сумма двух наибольших чисел строки не больше суммы трёх оставшихся чисел
#
# Файл к задаче: https://kompege.ru/files/IbVC7eDZ9x.xls
#
# ## Два типа решения
#
# ### Ручное решение (с использованием формул электронной таблицы)
#
# #### Шаг 1: Открываем файл
# ![открытый файл](images/one.png)
#
# #### Шаг 2: Проверяем первое условие (все числа различны)
#
# **Формула для проверки уникальности каждого числа:**

# %%
СЧЁТЕСЛИ($A1:$E1;A1)
# Out:
#   Cell In[1], line 1
#     СЧЁТЕСЛИ($A1:$E1;A1)
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Объяснение:** Эта формула подсчитывает, сколько раз значение из ячейки A1 встречается в диапазоне A1:E1. Если число уникальное, результат будет равен 1.
#
# ![формула](images/two.png)
#
# **Результат:** Для первого числа 97 формула показывает значение 1, так как это число встречается один раз.
#
# ![формула](images/i3.png)
#
# **Растягиваем формулу на все ячейки строки:**
#
# ![формула](images/g4.gif)
#
# **Проверяем выполнение первого условия для всей строки:**
# ЕСЛИ(СЧЁТЕСЛИ(F1:J1;1)=5;1;0)
#
# **Объяснение:** Эта формула проверяет, что во всех пяти ячейках (F1:J1) стоит значение 1, что означает все числа уникальны. Если условие выполняется, возвращает 1, иначе 0.
#
# ![формула](images/g5.gif)
#
# **Применяем формулы ко всем строкам:**
#
# ![формула](images/g6.gif)
#
# **Объяснение:** На примере видно, что в 7-й строке есть повторения, поэтому в столбце K отображается значение 0.
#
# #### Шаг 3: Проверяем второе условие (сумма двух наибольших ≤ суммы трёх оставшихся)
#
# **Находим два наибольших числа:**
# НАИБОЛЬШИЙ(A1:E1;1) - первое наибольшее
# НАИБОЛЬШИЙ(A1:E1;2) - второе наибольшее
#
# **Объяснение:** Функция НАИБОЛЬШИЙ возвращает k-ое наибольшее значение из диапазона.
#
# ![формула](images/g7.gif)
#
# **Объяснение:** В первой строке два наибольших числа - 97 и 96.
#
# **Находим сумму двух наибольших чисел:**
# НАИБОЛЬШИЙ(A1:E1;1)+НАИБОЛЬШИЙ(A1:E1;2)
#
# ![формула](images/g8.gif)
#
# **Находим сумму оставшихся трёх чисел:**
# СУММ(A1:E1)-(НАИБОЛЬШИЙ(A1:E1;1)+НАИБОЛЬШИЙ(A1:E1;2))
#
# **Объяснение:** Из общей суммы всех пяти чисел вычитаем сумму двух наибольших.
#
# ![формула](images/g9.gif)
#
# **Сравниваем суммы:**
# (НАИБОЛЬШИЙ(A1:E1;1)+НАИБОЛЬШИЙ(A1:E1;2))<=(СУММ(A1:E1)-(НАИБОЛЬШИЙ(A1:E1;1)+НАИБОЛЬШИЙ(A1:E1;2)))
#
# **Объяснение:** Проверяем, что сумма двух наибольших чисел меньше или равна сумме трёх оставшихся.
#
# ![формула](images/g10.gif)
#
# **Объяснение:** Видно, что первая строка не выполняет второе условие.
#
# **Применяем формулы ко всем строкам:**
# ![формула](images/g11.gif)
#
# **Объяснение:** На примере видно, что только 7-я строка подходит под второе условие.
#
# #### Шаг 4: Визуализация результатов
#
# **Условное форматирование для наглядности:**
# ![формула](images/g12.gif)
#
# **Объяснение:** Красным цветом выделены ячейки, где условие не выполняется (значение 0).
#
# #### Шаг 5: Проверяем выполнение обоих условий
#
# **Формула для проверки обоих условий:**
# ЕСЛИ(И(K1=1;P1=1);1;0)
#
# **Объяснение:** Формула возвращает 1, если оба условия выполняются (в столбцах K и P стоят единицы).
#
# ![формула](images/g13.gif)
#
# **Визуализация итогового результата:**
# ![формула](images/g14.gif)
#
# #### Шаг 6: Подсчёт результата
#
# **Формула для подсчёта подходящих строк:**
# СУММ(Q:Q)
#
# **Объяснение:** Суммируем все единицы в столбце Q, где отмечены строки, удовлетворяющие обоим условиям.
#
# ![формула](images/g15.gif)
#
# **Ответ:** 1922

# %% [markdown]
# ## Программное решение
#
# ### Подготовка файла
#
# Для работы с данными в Python необходимо преобразовать файл в формат CSV.
#
# **Процесс преобразования:**
# ![преобразование в CSV](images/g16.gif)
#
# **Объяснение:** Сохраняем файл электронной таблицы в формате CSV для удобства чтения в Python.
#
# ### Размещение файла
#
# Перемещаем CSV-файл в директорию с Python-скриптом:
# ![размещение файла](images/g17.gif)
#
# **Объяснение:** Файл данных должен находиться в той же папке, что и исполняемый скрипт, для простоты обращения к нему.

# %%
# Открываем файл '9_21895.csv' и читаем все строки в список
file = open('9_21895.csv').readlines()

# Инициализируем счетчик
c = 0

# Обрабатываем каждую строку из файла
for s in file:
    # Преобразуем строку в список целых чисел, разделенных запятыми
    # Сортируем список по возрастанию
    s = sorted(list(map(int, s.split(','))))
    
    # Создаем множество set() из элементов строки (убираем дубликаты)
    # Проверяем, что все числа в строке уникальны (длина множества равна длине списка)
    if len(set(s)) == len(s):
        
        # Сумма двух наибольших элементов (последние два в отсортированном списке)
        sum_max_s = s[-1] + s[-2]
        
        # Сумма всех остальных элементов (общая сумма минус два наибольших)
        sum_s = sum(s) - sum_max_s
        
        # Проверяем, что сумма двух наибольших не превышает сумму остальных
        if sum_max_s <= sum_s:
            c += 1

# Выводим количество строк, удовлетворяющих условиям
print(c)
# Out:
# 1922

# %% [markdown]
# ## Код без коментариев

# %%
file = open('9_21895.csv').readlines()
c = 0
for s in file:
    s = sorted(list(map(int, s.split(','))))
    if len(set(s)) == len(s):
        sum_max_s = s[-1] + s[-2]
        sum_s = sum(s)-sum_max_s
        if sum_max_s <= sum_s:
            c+=1
print(c)
# Out:
# 1922

# %% [markdown]
# # 📚 Лекции по решению 8 задания ЕГЭ
#
# Курс лекций по комбинаторике и программированию для решения 8 задания ЕГЭ по информатике.
#
# ## 📋 Структура курса
#
# Курс разделен на два основных модуля, изучение которых рекомендуется в строгой последовательности:
#
# ### 1. 📊 Задачи с цифрами (Обязательно к изучению первым)
# *Базовый модуль, посвященный работе с числовыми комбинациями и системами счисления.*
#
# - **Лекция 1**: Количество чисел с ограничениями в семеричной системе
#   - Ручной комбинаторный расчет
#   - Решение через вложенные циклы
#   - Оптимальное решение через itertools.product
#
# - **Лекция 2**: Числа с чередованием четности цифр
#   - Условие попарного чередования четности
#   - Решение с преобразованием паттернов
#   - Метод замены символов для проверки условий
#
# ### 2. 🔤 Задачи с буквами (Изучать после цифр)
# *Продвинутый модуль, focusing на работе с буквенными комбинациями и их нумерацией.*
#
# - **Лекция 3**: Поиск номера комбинации в упорядоченном списке
#   - Определение алфавитного порядка
#   - Кодирование букв в числовую систему
#   - Перевод между системами счисления
#
# - **Лекция 4**: Сложные условия с буквенными комбинациями
#   - Ограничения на повторения букв
#   - Условия на соседство символов
#   - Поиск конкретных позиций в ordered списке
#
# ## 🎯 Рекомендуемый порядок изучения
#
# !> **ВАЖНО:** Настоятельно рекомендуется изучать лекции в предложенном порядке:
#
# 1. **Начните с папки `задачи с цифрами`** - это основа для понимания комбинаторных принципов
# 2. **Затем переходите к папке `задачи с буквами`** - более сложные концепции строятся на базе первого модуля

# %% [markdown]
# <div style="background:#1a2235;border-radius:12px;padding:28px 32px;margin-bottom:4px;border:1px solid #1e2d47;"><div style="display:flex;align-items:center;gap:18px;margin-bottom:16px;"><div style="background:#3b82f6;color:#fff;font-size:28px;font-weight:800;border-radius:10px;width:60px;height:60px;display:flex;align-items:center;justify-content:center;flex-shrink:0;font-family:sans-serif;">2</div><div><div style="color:#64748b;font-size:11px;font-weight:600;letter-spacing:2px;text-transform:uppercase;margin-bottom:5px;font-family:sans-serif;">ЕГЭ ПО ИНФОРМАТИКЕ</div><div style="color:#fff;font-size:22px;font-weight:700;line-height:1.2;font-family:sans-serif;">Таблицы истинности · Алгебра логики</div><div style="color:#94a3b8;font-size:13px;margin-top:8px;font-family:sans-serif;">Логические операции · Порядок выполнения · Ручное решение · Перебор на Python</div></div></div><div style="display:flex;gap:8px;flex-wrap:wrap;"><span style="background:#1e2d47;color:#94a3b8;font-size:11px;font-weight:600;padding:4px 10px;border-radius:6px;font-family:sans-serif;">Алгебра логики</span><span style="background:#1e2d47;color:#94a3b8;font-size:11px;font-weight:600;padding:4px 10px;border-radius:6px;font-family:sans-serif;">Таблицы истинности</span><span style="background:#1e2d47;color:#94a3b8;font-size:11px;font-weight:600;padding:4px 10px;border-radius:6px;font-family:sans-serif;">Python</span><span style="background:#1c2a1a;color:#10b981;font-size:11px;font-weight:600;padding:4px 10px;border-radius:6px;font-family:sans-serif;">2 метода</span></div></div>

# %% [markdown]
# ## О задании
#
# Задание 2 ЕГЭ по информатике — **базовый** уровень, до 3 минут на решение.
#
# **Условие:** дана логическая функция и **неполная** таблица истинности (3 строки из 16 возможных). Нужно определить, какому столбцу соответствует каждая переменная.
#
# **Два метода:**
#
# | Метод | Когда | Суть |
# |:---:|:---|:---|
# | **Ручной** | Простые функции | Анализ структуры → строим свою таблицу → сопоставляем со столбцами |
# | **Перебор (Python)** | Любые функции | Перебираем все 16 комбинаций, выводим нужные строки |

# %% [markdown]
# <hr style="border:none;border-top:1px solid #1e2d47;margin:28px 0;">
# ## Операции алгебры логики

# %% [markdown]
# <div style="background:#1a2235;border-radius:8px;border:1px solid #1e2d47;padding:18px 22px;margin:12px 0;"><div style="display:flex;align-items:center;gap:12px;margin-bottom:12px;"><span style="background:#3b82f6;color:#fff;font-family:monospace;font-size:17px;font-weight:800;padding:4px 14px;border-radius:6px;">¬A</span><div><div style="color:#e2e8f0;font-size:15px;font-weight:700;font-family:sans-serif;">Инверсия — логическое НЕ</div><div style="color:#94a3b8;font-size:12px;font-family:monospace;margin-top:2px;">Python: <code style="background:#0d1629;padding:2px 6px;border-radius:3px;color:#10b981;">not a</code></div></div></div><div style="color:#94a3b8;font-size:13px;font-family:sans-serif;margin-bottom:12px;">Меняет значение на противоположное. Единственная <b>унарная</b> операция (один аргумент).</div><div style="display:flex;align-items:flex-start;gap:16px;flex-wrap:wrap;"><div><table style="border-collapse:collapse;margin:8px 0;"><thead><tr><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">A</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">¬A</th></tr></thead><tbody><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr></tbody></table></div><img src="data:image/png;base64,..." alt="Инверсия — логическое НЕ" style="max-width:100%;border-radius:6px;display:block;width:300px;margin-top:4px;flex-shrink:0;"/></div></div>

# %% [markdown]
# <div style="background:#1a2235;border-radius:8px;border:1px solid #1e2d47;padding:18px 22px;margin:12px 0;"><div style="display:flex;align-items:center;gap:12px;margin-bottom:12px;"><span style="background:#3b82f6;color:#fff;font-family:monospace;font-size:17px;font-weight:800;padding:4px 14px;border-radius:6px;">A∧B</span><div><div style="color:#e2e8f0;font-size:15px;font-weight:700;font-family:sans-serif;">Конъюнкция — логическое И</div><div style="color:#94a3b8;font-size:12px;font-family:monospace;margin-top:2px;">Python: <code style="background:#0d1629;padding:2px 6px;border-radius:3px;color:#10b981;">a and b</code></div></div></div><div style="color:#94a3b8;font-size:13px;font-family:sans-serif;margin-bottom:12px;">Истина только когда <b>оба</b> аргумента истинны.</div><div style="display:flex;align-items:flex-start;gap:16px;flex-wrap:wrap;"><div><table style="border-collapse:collapse;margin:8px 0;"><thead><tr><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">A</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">B</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">A∧B</th></tr></thead><tbody><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td></tr></tbody></table></div><img src="data:image/png;base64,..." alt="Конъюнкция — логическое И" style="max-width:100%;border-radius:6px;display:block;width:300px;margin-top:4px;flex-shrink:0;"/></div></div>

# %% [markdown]
# <div style="background:#1a2235;border-radius:8px;border:1px solid #1e2d47;padding:18px 22px;margin:12px 0;"><div style="display:flex;align-items:center;gap:12px;margin-bottom:12px;"><span style="background:#3b82f6;color:#fff;font-family:monospace;font-size:17px;font-weight:800;padding:4px 14px;border-radius:6px;">A∨B</span><div><div style="color:#e2e8f0;font-size:15px;font-weight:700;font-family:sans-serif;">Дизъюнкция — логическое ИЛИ</div><div style="color:#94a3b8;font-size:12px;font-family:monospace;margin-top:2px;">Python: <code style="background:#0d1629;padding:2px 6px;border-radius:3px;color:#10b981;">a or b</code></div></div></div><div style="color:#94a3b8;font-size:13px;font-family:sans-serif;margin-bottom:12px;">Истина когда <b>хотя бы один</b> аргумент истинен. Ложна только при A=0 и B=0.</div><div style="display:flex;align-items:flex-start;gap:16px;flex-wrap:wrap;"><div><table style="border-collapse:collapse;margin:8px 0;"><thead><tr><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">A</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">B</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">A∨B</th></tr></thead><tbody><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td></tr></tbody></table></div><img src="data:image/png;base64,..." alt="Дизъюнкция — логическое ИЛИ" style="max-width:100%;border-radius:6px;display:block;width:300px;margin-top:4px;flex-shrink:0;"/></div></div>

# %% [markdown]
# <div style="background:#1a2235;border-radius:8px;border:1px solid #1e2d47;padding:18px 22px;margin:12px 0;"><div style="display:flex;align-items:center;gap:12px;margin-bottom:12px;"><span style="background:#3b82f6;color:#fff;font-family:monospace;font-size:17px;font-weight:800;padding:4px 14px;border-radius:6px;">A→B</span><div><div style="color:#e2e8f0;font-size:15px;font-weight:700;font-family:sans-serif;">Импликация — логическое СЛЕДОВАНИЕ</div><div style="color:#94a3b8;font-size:12px;font-family:monospace;margin-top:2px;">Python: <code style="background:#0d1629;padding:2px 6px;border-radius:3px;color:#10b981;">a <= b</code></div></div></div><div style="color:#94a3b8;font-size:13px;font-family:sans-serif;margin-bottom:12px;">Ложна <b>только</b> при A=1, B=0. Во всех остальных случаях истинна.</div><div style="display:flex;align-items:flex-start;gap:16px;flex-wrap:wrap;"><div><table style="border-collapse:collapse;margin:8px 0;"><thead><tr><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">A</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">B</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">A→B</th></tr></thead><tbody><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td></tr></tbody></table><div style="background:#1c1000;border-left:3px solid #f59e0b;border-radius:0 4px 4px 0;padding:6px 12px;margin-top:8px;font-size:12px;font-family:monospace;color:#94a3b8;">⚠️  Единственная ложная строка: A=<span style="color:#ef4444;">1</span>, B=<span style="color:#ef4444;">0</span></div></div><img src="data:image/png;base64,..." alt="Импликация — логическое СЛЕДОВАНИЕ" style="max-width:100%;border-radius:6px;display:block;width:300px;margin-top:4px;flex-shrink:0;"/></div></div>

# %% [markdown]
# <div style="background:#1a2235;border-radius:8px;border:1px solid #1e2d47;padding:18px 22px;margin:12px 0;"><div style="display:flex;align-items:center;gap:12px;margin-bottom:12px;"><span style="background:#3b82f6;color:#fff;font-family:monospace;font-size:17px;font-weight:800;padding:4px 14px;border-radius:6px;">A≡B</span><div><div style="color:#e2e8f0;font-size:15px;font-weight:700;font-family:sans-serif;">Эквивалентность — логическое РАВЕНСТВО</div><div style="color:#94a3b8;font-size:12px;font-family:monospace;margin-top:2px;">Python: <code style="background:#0d1629;padding:2px 6px;border-radius:3px;color:#10b981;">a == b</code></div></div></div><div style="color:#94a3b8;font-size:13px;font-family:sans-serif;margin-bottom:12px;">Истина когда оба аргумента <b>одинаковы</b> (оба 0 или оба 1).</div><div style="display:flex;align-items:flex-start;gap:16px;flex-wrap:wrap;"><div><table style="border-collapse:collapse;margin:8px 0;"><thead><tr><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">A</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">B</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">A≡B</th></tr></thead><tbody><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td></tr></tbody></table></div><img src="data:image/png;base64,..." alt="Эквивалентность — логическое РАВЕНСТВО" style="max-width:100%;border-radius:6px;display:block;width:300px;margin-top:4px;flex-shrink:0;"/></div></div>

# %% [markdown]
# <hr style="border:none;border-top:1px solid #1e2d47;margin:28px 0;">
# ## Приоритет операций
#
# > ⚠️ **Главная ловушка:**  и  в Python выполняются **раньше** , ,  — противоположно порядку в алгебре логики.
#
# <div style="background:#1a2235;border-radius:8px;border:1px solid #1e2d47;padding:16px 20px;margin:12px 0;display:inline-block;max-width:100%"><div style="display:flex;gap:24px;align-items:flex-start;flex-wrap:wrap;"><div><table style="border-collapse:collapse;"><thead><tr><th colspan="3" style="padding:8px 10px;font-family:monospace;font-size:12px;font-weight:700;color:#94a3b8;background:#0a1628;border:1px solid #1e2d47;text-align:center;">Алгебра логики</th></tr></thead><tbody><tr><td style="padding:6px 8px;font-family:monospace;font-size:12px;color:#475569;border:1px solid #1e2d47;background:#0d1629;width:28px;text-align:right;">1.</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#f59e0b;border:1px solid #1e2d47;background:#0d1629;width:52px;font-weight:700;">( )</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#f59e0b;border:1px solid #1e2d47;background:#0d1629;font-weight:700;">Скобки</td></tr><tr><td style="padding:6px 8px;font-family:monospace;font-size:12px;color:#475569;border:1px solid #1e2d47;background:#0d1629;width:28px;text-align:right;">2.</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#10b981;border:1px solid #1e2d47;background:#0d1629;width:52px;font-weight:700;">¬</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#10b981;border:1px solid #1e2d47;background:#0d1629;font-weight:700;">Инверсия</td></tr><tr><td style="padding:6px 8px;font-family:monospace;font-size:12px;color:#475569;border:1px solid #1e2d47;background:#0d1629;width:28px;text-align:right;">3.</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#3b82f6;border:1px solid #1e2d47;background:#0d1629;width:52px;font-weight:700;">∧</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#3b82f6;border:1px solid #1e2d47;background:#0d1629;font-weight:700;">Конъюнкция</td></tr><tr><td style="padding:6px 8px;font-family:monospace;font-size:12px;color:#475569;border:1px solid #1e2d47;background:#0d1629;width:28px;text-align:right;">4.</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#e2e8f0;border:1px solid #1e2d47;background:#0d1629;width:52px;font-weight:700;">∨</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#e2e8f0;border:1px solid #1e2d47;background:#0d1629;font-weight:700;">Дизъюнкция</td></tr><tr><td style="padding:6px 8px;font-family:monospace;font-size:12px;color:#475569;border:1px solid #1e2d47;background:#0d1629;width:28px;text-align:right;">5.</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#94a3b8;border:1px solid #1e2d47;background:#0d1629;width:52px;font-weight:700;">→</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#94a3b8;border:1px solid #1e2d47;background:#0d1629;font-weight:700;">Импликация</td></tr><tr><td style="padding:6px 8px;font-family:monospace;font-size:12px;color:#475569;border:1px solid #1e2d47;background:#0d1629;width:28px;text-align:right;">6.</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#475569;border:1px solid #1e2d47;background:#0d1629;width:52px;font-weight:700;">≡</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#475569;border:1px solid #1e2d47;background:#0d1629;font-weight:700;">Эквивалентность</td></tr></tbody></table></div><div style="width:1px;background:#1e2d47;align-self:stretch;"></div><div><table style="border-collapse:collapse;"><thead><tr><th colspan="3" style="padding:8px 10px;font-family:monospace;font-size:12px;font-weight:700;color:#94a3b8;background:#0a1628;border:1px solid #1e2d47;text-align:center;">Python</th></tr></thead><tbody><tr><td style="padding:6px 8px;font-family:monospace;font-size:12px;color:#475569;border:1px solid #1e2d47;background:#0d1629;width:28px;text-align:right;">1.</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#f59e0b;border:1px solid #1e2d47;background:#0d1629;width:52px;font-weight:700;">( )</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#f59e0b;border:1px solid #1e2d47;background:#0d1629;font-weight:700;">Скобки</td></tr><tr><td style="padding:6px 8px;font-family:monospace;font-size:12px;color:#475569;border:1px solid #1e2d47;background:#0d1629;width:28px;text-align:right;">2.</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#ef4444;border:1px solid #1e2d47;background:#0d1629;width:52px;font-weight:700;"><= ==</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#ef4444;border:1px solid #1e2d47;background:#0d1629;font-weight:700;">Импликация, Эквивал.</td></tr><tr><td style="padding:6px 8px;font-family:monospace;font-size:12px;color:#475569;border:1px solid #1e2d47;background:#0d1629;width:28px;text-align:right;">3.</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#10b981;border:1px solid #1e2d47;background:#0d1629;width:52px;font-weight:700;">not</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#10b981;border:1px solid #1e2d47;background:#0d1629;font-weight:700;">Инверсия</td></tr><tr><td style="padding:6px 8px;font-family:monospace;font-size:12px;color:#475569;border:1px solid #1e2d47;background:#0d1629;width:28px;text-align:right;">4.</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#3b82f6;border:1px solid #1e2d47;background:#0d1629;width:52px;font-weight:700;">and</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#3b82f6;border:1px solid #1e2d47;background:#0d1629;font-weight:700;">Конъюнкция</td></tr><tr><td style="padding:6px 8px;font-family:monospace;font-size:12px;color:#475569;border:1px solid #1e2d47;background:#0d1629;width:28px;text-align:right;">5.</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#e2e8f0;border:1px solid #1e2d47;background:#0d1629;width:52px;font-weight:700;">or</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#e2e8f0;border:1px solid #1e2d47;background:#0d1629;font-weight:700;">Дизъюнкция</td></tr><tr><td style="padding:6px 8px;font-family:monospace;font-size:12px;color:#475569;border:1px solid #1e2d47;background:#0d1629;width:28px;text-align:right;">6.</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#475569;border:1px solid #1e2d47;background:#0d1629;width:52px;font-weight:700;">—</td><td style="padding:6px 10px;font-family:monospace;font-size:13px;color:#475569;border:1px solid #1e2d47;background:#0d1629;font-weight:700;"></td></tr></tbody></table></div></div><div style="color:#ef4444;font-size:12px;font-family:sans-serif;text-align:center;margin-top:10px;font-style:italic;">⚠  &lt;= и == в Python выполняются РАНЬШЕ not / and / or !</div></div>

# %% [markdown]
# <div style="background:#1c1700;border-left:3px solid #f59e0b;border-radius:0 6px 6px 0;padding:12px 18px;margin:12px 0;font-size:14px;color:#94a3b8;font-family:sans-serif;"><b style="color:#f59e0b;">Практическое правило:</b> если <code>&lt;=</code> или <code>==</code> стоят не последними по порядку алгебры — оберни в скобки.<br><br>Пример: <b>x ≡ y ∧ z</b> (порядок: сначала ∧, потом ≡)<br>❌ <code>x == y and z</code> — неверно (<code>==</code> выполнится первым!)<br>✅ <code>x == (y and z)</code> — верно</div>

# %% [markdown]
# <hr style="border:none;border-top:1px solid #1e2d47;margin:28px 0;">
# ## Метод 1 — Ручное решение
#
# **Алгоритм:**
# 1. Определить, при каких условиях F = 0 — разобрать структуру выражения
# 2. Записать значения переменных в свою таблицу
# 3. Сопоставить столбцы своей таблицы с таблицей из условия

# %% [markdown]
# <div style="background:#1a2235;border:1px solid #2a3a5c;border-left:3px solid #f59e0b;border-radius:8px;padding:18px 22px;margin:16px 0;"><div style="color:#f59e0b;font-size:12px;font-weight:700;letter-spacing:1px;text-transform:uppercase;margin-bottom:10px;font-family:sans-serif;">📋 Задание 200 — Ручной метод — разбор</div><div style="color:#e2e8f0;line-height:1.8;font-size:14px;font-family:sans-serif;">F = (z → ¬(y → x)) ∨ w<br><br><div style="color:#94a3b8;font-size:13px;font-family:sans-serif;line-height:1.6;margin-bottom:12px;">Миша заполнял таблицу истинности логической функции, но успел заполнить лишь фрагмент из трёх различных её строк, даже не указав, какому столбцу таблицы соответствует каждая из переменных.<br>Определите, какому столбцу таблицы соответствует каждая из переменных w, x, y, z. В ответе напишите буквы w, x, y, z в том порядке, в котором идут соответствующие им столбцы (сначала буква, соответствующая первому столбцу и т.д.). Буквы в ответе пишите подряд, без разделителей.</div><div style="margin:8px 0;"><div style="color:#475569;font-size:11px;font-weight:600;letter-spacing:0.5px;text-transform:uppercase;margin-bottom:6px;font-family:sans-serif;">Фрагмент таблицы из условия</div><table style="border-collapse:collapse;"><thead><tr><th style="padding:7px 16px;font-family:monospace;font-size:13px;background:#0d1629;border:1px solid #1e2d47;font-weight:700;color:#475569;"></th><th style="padding:7px 16px;font-family:monospace;font-size:13px;background:#0d1629;border:1px solid #1e2d47;font-weight:700;color:#475569;"></th><th style="padding:7px 16px;font-family:monospace;font-size:13px;background:#0d1629;border:1px solid #1e2d47;font-weight:700;color:#475569;"></th><th style="padding:7px 16px;font-family:monospace;font-size:13px;background:#0d1629;border:1px solid #1e2d47;font-weight:700;color:#475569;"></th><th style="padding:7px 16px;font-family:monospace;font-size:13px;background:#0d1629;border:1px solid #1e2d47;font-weight:700;color:#f59e0b;">F</th></tr></thead><tbody><tr><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#0f1f35;font-weight:700;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#0f1f35;font-weight:700;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#0f1f35;font-weight:700;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr></tbody></table></div>Определить, какому столбцу соответствует каждая из переменных w, x, y, z.<div style="margin-top:12px;padding:8px 14px;background:#0f1f12;border-radius:6px;font-family:monospace;font-size:13px;color:#10b981;">✅ Ответ: zyxw</div></div></div>

# %% [markdown]
# <div style="display:inline-flex;align-items:flex-start;gap:10px;margin:4px 0;background:#1a2235;border:1px solid #1e2d47;border-left:3px solid #f59e0b;border-radius:6px;padding:8px 12px;max-width:fit-content;"><div style="background:#f59e0b;color:#000;font-weight:800;font-size:11px;border-radius:4px;padding:2px 8px;white-space:nowrap;flex-shrink:0;font-family:sans-serif;margin-top:1px;">шаг 1</div><div style="font-family:monospace;font-size:13px;color:#94a3b8;line-height:1.7;">F = 0 → дизъюнкция ложна → оба операнда ложны<br><span style="color:#94a3b8;font-size:11px;font-style:italic;">→ <b style="color:#10b981;">w = 0</b> всегда &nbsp;→ <b style="color:#10b981;">z = 1</b> (иначе импликация z→... была бы истиной) &nbsp;→ (y→x) должна быть истинной</span></div></div><br>
# <div style="color:#475569;font-size:11px;font-weight:600;letter-spacing:0.5px;text-transform:uppercase;margin:10px 0 4px;font-family:sans-serif;">После шага 1: z и w известны</div><table style="border-collapse:collapse;margin:4px 0;"><thead><tr><th style="padding:6px 14px;font-family:monospace;font-size:12px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">z</th><th style="padding:6px 14px;font-family:monospace;font-size:12px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">y</th><th style="padding:6px 14px;font-family:monospace;font-size:12px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">x</th><th style="padding:6px 14px;font-family:monospace;font-size:12px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">w</th></tr></thead><tbody><tr><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#475569;">?</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#475569;">?</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#475569;">?</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#475569;">?</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#475569;">?</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#475569;">?</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr></tbody></table>
# <div style="display:inline-flex;align-items:flex-start;gap:10px;margin:4px 0;background:#1a2235;border:1px solid #1e2d47;border-left:3px solid #f59e0b;border-radius:6px;padding:8px 12px;max-width:fit-content;"><div style="background:#f59e0b;color:#000;font-weight:800;font-size:11px;border-radius:4px;padding:2px 8px;white-space:nowrap;flex-shrink:0;font-family:sans-serif;margin-top:1px;">шаг 2</div><div style="font-family:monospace;font-size:13px;color:#94a3b8;line-height:1.7;">y → x = 1: три варианта (y,x) = (0,0), (0,1), (1,1) — все кроме (1,0)</div></div><br>
# <div style="color:#475569;font-size:11px;font-weight:600;letter-spacing:0.5px;text-transform:uppercase;margin:10px 0 4px;font-family:sans-serif;">После шага 2: своя таблица истинности</div><table style="border-collapse:collapse;margin:4px 0;"><thead><tr><th style="padding:6px 14px;font-family:monospace;font-size:12px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">z</th><th style="padding:6px 14px;font-family:monospace;font-size:12px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">y</th><th style="padding:6px 14px;font-family:monospace;font-size:12px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">x</th><th style="padding:6px 14px;font-family:monospace;font-size:12px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">w</th></tr></thead><tbody><tr><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr></tbody></table>
# <div style="display:inline-flex;align-items:flex-start;gap:10px;margin:4px 0;background:#1a2235;border:1px solid #1e2d47;border-left:3px solid #f59e0b;border-radius:6px;padding:8px 12px;max-width:fit-content;"><div style="background:#f59e0b;color:#000;font-weight:800;font-size:11px;border-radius:4px;padding:2px 8px;white-space:nowrap;flex-shrink:0;font-family:sans-serif;margin-top:1px;">шаг 3</div><div style="font-family:monospace;font-size:13px;color:#94a3b8;line-height:1.7;">Сопоставляем с таблицей из условия<br><span style="color:#94a3b8;font-size:11px;font-style:italic;">4-й столбец — одни нули → <b style="color:#10b981;">w</b> &nbsp;&nbsp; 1-й столбец — одни единицы → <b style="color:#10b981;">z</b><br>💬 Последняя строка (2-й, 3-й): (1,1) → это (y=1, x=1) → 2-й = <b style="color:#10b981;">y</b>, 3-й = <b style="color:#10b981;">x</b></span></div></div><br>
#
# <div style="margin-top:8px;"><table style="border-collapse:collapse;margin:8px 0;"><thead><tr><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">z</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">y</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">x</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">w</th></tr></thead><tbody><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr></tbody></table></div>

# %% [markdown]
# <div style="background:#1a2235;border:1px solid #2a3a5c;border-left:3px solid #f59e0b;border-radius:8px;padding:18px 22px;margin:16px 0;"><div style="color:#f59e0b;font-size:12px;font-weight:700;letter-spacing:1px;text-transform:uppercase;margin-bottom:10px;font-family:sans-serif;">📋 Задание 201 — Ручной метод — пример</div><div style="color:#e2e8f0;line-height:1.8;font-size:14px;font-family:sans-serif;">F = ¬(x → z) ∨ (y ≡ w) ∨ y<br><br><div style="color:#94a3b8;font-size:13px;font-family:sans-serif;line-height:1.6;margin-bottom:12px;">Миша заполнял таблицу истинности логической функции, но успел заполнить лишь фрагмент из трёх различных её строк, даже не указав, какому столбцу таблицы соответствует каждая из переменных.<br>Определите, какому столбцу таблицы соответствует каждая из переменных w, x, y, z. В ответе напишите буквы w, x, y, z в том порядке, в котором идут соответствующие им столбцы (сначала буква, соответствующая первому столбцу и т.д.). Буквы в ответе пишите подряд, без разделителей.</div><div style="margin:8px 0;"><div style="color:#475569;font-size:11px;font-weight:600;letter-spacing:0.5px;text-transform:uppercase;margin-bottom:6px;font-family:sans-serif;">Фрагмент таблицы из условия</div><table style="border-collapse:collapse;"><thead><tr><th style="padding:7px 16px;font-family:monospace;font-size:13px;background:#0d1629;border:1px solid #1e2d47;font-weight:700;color:#475569;"></th><th style="padding:7px 16px;font-family:monospace;font-size:13px;background:#0d1629;border:1px solid #1e2d47;font-weight:700;color:#475569;"></th><th style="padding:7px 16px;font-family:monospace;font-size:13px;background:#0d1629;border:1px solid #1e2d47;font-weight:700;color:#475569;"></th><th style="padding:7px 16px;font-family:monospace;font-size:13px;background:#0d1629;border:1px solid #1e2d47;font-weight:700;color:#475569;"></th><th style="padding:7px 16px;font-family:monospace;font-size:13px;background:#0d1629;border:1px solid #1e2d47;font-weight:700;color:#f59e0b;">F</th></tr></thead><tbody><tr><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#0f1f35;font-weight:700;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#0f1f35;font-weight:700;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#0f1f35;font-weight:700;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr></tbody></table></div>Определить, какому столбцу соответствует каждая из переменных w, x, y, z.<div style="margin-top:12px;padding:8px 14px;background:#0f1f12;border-radius:6px;font-family:monospace;font-size:13px;color:#10b981;">✅ Ответ: zxyw</div></div></div>

# %% [markdown]
# <div style="display:inline-flex;align-items:flex-start;gap:10px;margin:4px 0;background:#1a2235;border:1px solid #1e2d47;border-left:3px solid #f59e0b;border-radius:6px;padding:8px 12px;max-width:fit-content;"><div style="background:#f59e0b;color:#000;font-weight:800;font-size:11px;border-radius:4px;padding:2px 8px;white-space:nowrap;flex-shrink:0;font-family:sans-serif;margin-top:1px;">шаг 1</div><div style="font-family:monospace;font-size:13px;color:#94a3b8;line-height:1.7;">F = 0 → все три операнда ложны<br><span style="color:#94a3b8;font-size:11px;font-style:italic;">→ <b style="color:#10b981;">y = 0</b> всегда &nbsp;→ y ≡ w = 0 → y ≠ w → <b style="color:#10b981;">w = 1</b></span></div></div><br>
# <div style="color:#475569;font-size:11px;font-weight:600;letter-spacing:0.5px;text-transform:uppercase;margin:10px 0 4px;font-family:sans-serif;">После шага 1: y и w известны</div><table style="border-collapse:collapse;margin:4px 0;"><thead><tr><th style="padding:6px 14px;font-family:monospace;font-size:12px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">x</th><th style="padding:6px 14px;font-family:monospace;font-size:12px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">z</th><th style="padding:6px 14px;font-family:monospace;font-size:12px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">y</th><th style="padding:6px 14px;font-family:monospace;font-size:12px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">w</th></tr></thead><tbody><tr><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#475569;">?</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#475569;">?</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td></tr><tr><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#475569;">?</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#475569;">?</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td></tr><tr><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#475569;">?</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#475569;">?</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td></tr></tbody></table>
# <div style="display:inline-flex;align-items:flex-start;gap:10px;margin:4px 0;background:#1a2235;border:1px solid #1e2d47;border-left:3px solid #f59e0b;border-radius:6px;padding:8px 12px;max-width:fit-content;"><div style="background:#f59e0b;color:#000;font-weight:800;font-size:11px;border-radius:4px;padding:2px 8px;white-space:nowrap;flex-shrink:0;font-family:sans-serif;margin-top:1px;">шаг 2</div><div style="font-family:monospace;font-size:13px;color:#94a3b8;line-height:1.7;">¬(x → z) = 0 → (x → z) = 1: три варианта (x,z) = (0,0), (0,1), (1,1)</div></div><br>
# <div style="color:#475569;font-size:11px;font-weight:600;letter-spacing:0.5px;text-transform:uppercase;margin:10px 0 4px;font-family:sans-serif;">После шага 2: своя таблица истинности</div><table style="border-collapse:collapse;margin:4px 0;"><thead><tr><th style="padding:6px 14px;font-family:monospace;font-size:12px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">x</th><th style="padding:6px 14px;font-family:monospace;font-size:12px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">z</th><th style="padding:6px 14px;font-family:monospace;font-size:12px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">y</th><th style="padding:6px 14px;font-family:monospace;font-size:12px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">w</th></tr></thead><tbody><tr><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td></tr><tr><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td></tr><tr><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 14px;font-family:monospace;font-size:13px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td></tr></tbody></table>
# <div style="display:inline-flex;align-items:flex-start;gap:10px;margin:4px 0;background:#1a2235;border:1px solid #1e2d47;border-left:3px solid #f59e0b;border-radius:6px;padding:8px 12px;max-width:fit-content;"><div style="background:#f59e0b;color:#000;font-weight:800;font-size:11px;border-radius:4px;padding:2px 8px;white-space:nowrap;flex-shrink:0;font-family:sans-serif;margin-top:1px;">шаг 3</div><div style="font-family:monospace;font-size:13px;color:#94a3b8;line-height:1.7;">Сопоставляем с таблицей из условия<br><span style="color:#94a3b8;font-size:11px;font-style:italic;">4-й столбец — одни единицы → <b style="color:#10b981;">w</b> &nbsp;&nbsp; 3-й столбец — одни нули → <b style="color:#10b981;">y</b><br>💬 1-я строка (1-й, 2-й): (1,0) → это z=0, x=0 → 1-й = <b style="color:#10b981;">z</b>, 2-й = <b style="color:#10b981;">x</b></span></div></div><br>
#
# <div style="margin-top:8px;"><table style="border-collapse:collapse;margin:8px 0;"><thead><tr><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">z</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">x</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">y</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">w</th></tr></thead><tbody><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td></tr></tbody></table></div>

# %% [markdown]
# <hr style="border:none;border-top:1px solid #1e2d47;margin:28px 0;">
#
# ## Метод 2 — Перебор на Python
#
# Перебираем все 16 комбинаций (4 переменных × {0,1}) и выводим строки, где функция принимает нужное значение.
#
# ### Шаблон
#
# ```python
# print('x y z w')
# for x in 0, 1:
#     for y in 0, 1:
#         for z in 0, 1:
#             for w in 0, 1:
#                 f = (логическое_выражение)
#                 if not f:   # где F = 0
#                 # if f:     # где F = 1
#                     print(x, y, z, w)
# ```
#
# | Нужные строки | Условие |
# |:---:|:---:|
# | Где F = **0** | `if not f` |
# | Где F = **1** | `if f` |

# %% [markdown]
# <div style="background:#0d1f12;border-left:3px solid #10b981;border-radius:0 6px 6px 0;padding:12px 18px;margin:12px 0;font-size:14px;color:#94a3b8;font-family:sans-serif;"><b style="color:#10b981;">Шпаргалка перевода:</b><br><br><code>¬A</code> → <code>not a</code> &nbsp;&nbsp;<code>A ∧ B</code> → <code>a and b</code> &nbsp;&nbsp;<code>A ∨ B</code> → <code>a or b</code><br><code>A → B</code> → <code>a &lt;= b</code> &nbsp;&nbsp;<code>A ≡ B</code> → <code>a == b</code></div>

# %% [markdown]
# <div style="background:#1a2235;border:1px solid #2a3a5c;border-left:3px solid #f59e0b;border-radius:8px;padding:18px 22px;margin:16px 0;"><div style="color:#f59e0b;font-size:12px;font-weight:700;letter-spacing:1px;text-transform:uppercase;margin-bottom:10px;font-family:sans-serif;">📋 Задание 202 — Метод перебора — разбор</div><div style="color:#e2e8f0;line-height:1.8;font-size:14px;font-family:sans-serif;">F = ¬(x → w) ∨ (y → z) ∨ ¬y<br><br><div style="color:#94a3b8;font-size:13px;font-family:sans-serif;line-height:1.6;margin-bottom:12px;">Миша заполнял таблицу истинности логической функции, но успел заполнить лишь фрагмент из трёх различных её строк, даже не указав, какому столбцу таблицы соответствует каждая из переменных.<br>Определите, какому столбцу таблицы соответствует каждая из переменных w, x, y, z. В ответе напишите буквы w, x, y, z в том порядке, в котором идут соответствующие им столбцы (сначала буква, соответствующая первому столбцу и т.д.). Буквы в ответе пишите подряд, без разделителей.</div><div style="margin:8px 0;"><div style="color:#475569;font-size:11px;font-weight:600;letter-spacing:0.5px;text-transform:uppercase;margin-bottom:6px;font-family:sans-serif;">Фрагмент таблицы из условия</div><table style="border-collapse:collapse;"><thead><tr><th style="padding:7px 16px;font-family:monospace;font-size:13px;background:#0d1629;border:1px solid #1e2d47;font-weight:700;color:#475569;"></th><th style="padding:7px 16px;font-family:monospace;font-size:13px;background:#0d1629;border:1px solid #1e2d47;font-weight:700;color:#475569;"></th><th style="padding:7px 16px;font-family:monospace;font-size:13px;background:#0d1629;border:1px solid #1e2d47;font-weight:700;color:#475569;"></th><th style="padding:7px 16px;font-family:monospace;font-size:13px;background:#0d1629;border:1px solid #1e2d47;font-weight:700;color:#475569;"></th><th style="padding:7px 16px;font-family:monospace;font-size:13px;background:#0d1629;border:1px solid #1e2d47;font-weight:700;color:#f59e0b;">F</th></tr></thead><tbody><tr><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#0f1f35;font-weight:700;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#0f1f35;font-weight:700;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#0f1f35;font-weight:700;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr></tbody></table></div><div style="margin-top:12px;padding:8px 14px;background:#0f1f12;border-radius:6px;font-family:monospace;font-size:13px;color:#10b981;">✅ Ответ: yxwz</div></div></div>

# %%
# Задание 202 — ищем строки где F = 0
print("x y z w")
for x in 0, 1:
    for y in 0, 1:
        for z in 0, 1:
            for w in 0, 1:
                f = not (x <= w) or (y <= z) or not y
                if not f:
                    print(x, y, z, w)

# %% [markdown]
# <div style="display:inline-flex;align-items:flex-start;gap:10px;margin:4px 0;background:#1a2235;border:1px solid #1e2d47;border-left:3px solid #f59e0b;border-radius:6px;padding:8px 12px;max-width:fit-content;"><div style="background:#f59e0b;color:#000;font-weight:800;font-size:11px;border-radius:4px;padding:2px 8px;white-space:nowrap;flex-shrink:0;font-family:sans-serif;margin-top:1px;">шаг 1</div><div style="font-family:monospace;font-size:13px;color:#94a3b8;line-height:1.7;">Программа выводит 3 строки<br><span style="color:#94a3b8;font-size:11px;font-style:italic;"><code>0 1 0 0</code> &nbsp; <code>0 1 0 1</code> &nbsp; <code>1 1 0 1</code></span></div></div><br>
# <div style="display:inline-flex;align-items:flex-start;gap:10px;margin:4px 0;background:#1a2235;border:1px solid #1e2d47;border-left:3px solid #f59e0b;border-radius:6px;padding:8px 12px;max-width:fit-content;"><div style="background:#f59e0b;color:#000;font-weight:800;font-size:11px;border-radius:4px;padding:2px 8px;white-space:nowrap;flex-shrink:0;font-family:sans-serif;margin-top:1px;">шаг 2</div><div style="font-family:monospace;font-size:13px;color:#94a3b8;line-height:1.7;">Сопоставляем с таблицей из условия<br><span style="color:#94a3b8;font-size:11px;font-style:italic;">3-й столбец — одни нули → <b style="color:#10b981;">z</b> &nbsp;&nbsp; 2-й столбец — одни единицы → <b style="color:#10b981;">y</b><br>💬 2-я строка: (x,w) = (0,1) → похоже на импликацию x→w (x=0, w=1) ✓<br>→ 1-й = <b style="color:#10b981;">y</b>, 2-й = <b style="color:#10b981;">x</b>, 3-й = <b style="color:#10b981;">w</b>, 4-й = <b style="color:#10b981;">z</b></span></div></div><br>
#
# <div style="margin-top:8px;"><table style="border-collapse:collapse;margin:8px 0;"><thead><tr><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">y</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">x</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">w</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">z</th></tr></thead><tbody><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr></tbody></table></div>

# %% [markdown]
# <div style="background:#1a2235;border:1px solid #2a3a5c;border-left:3px solid #f59e0b;border-radius:8px;padding:18px 22px;margin:16px 0;"><div style="color:#f59e0b;font-size:12px;font-weight:700;letter-spacing:1px;text-transform:uppercase;margin-bottom:10px;font-family:sans-serif;">📋 Задание 203 — Метод перебора — пример</div><div style="color:#e2e8f0;line-height:1.8;font-size:14px;font-family:sans-serif;">F = (y → x) ∧ ¬z ∧ w<br><br><div style="color:#94a3b8;font-size:13px;font-family:sans-serif;line-height:1.6;margin-bottom:12px;">Миша заполнял таблицу истинности логической функции, но успел заполнить лишь фрагмент из трёх различных её строк, даже не указав, какому столбцу таблицы соответствует каждая из переменных.<br>Определите, какому столбцу таблицы соответствует каждая из переменных w, x, y, z. В ответе напишите буквы w, x, y, z в том порядке, в котором идут соответствующие им столбцы (сначала буква, соответствующая первому столбцу и т.д.). Буквы в ответе пишите подряд, без разделителей.</div><div style="margin:8px 0;"><div style="color:#475569;font-size:11px;font-weight:600;letter-spacing:0.5px;text-transform:uppercase;margin-bottom:6px;font-family:sans-serif;">Фрагмент таблицы из условия</div><table style="border-collapse:collapse;"><thead><tr><th style="padding:7px 16px;font-family:monospace;font-size:13px;background:#0d1629;border:1px solid #1e2d47;font-weight:700;color:#475569;"></th><th style="padding:7px 16px;font-family:monospace;font-size:13px;background:#0d1629;border:1px solid #1e2d47;font-weight:700;color:#475569;"></th><th style="padding:7px 16px;font-family:monospace;font-size:13px;background:#0d1629;border:1px solid #1e2d47;font-weight:700;color:#475569;"></th><th style="padding:7px 16px;font-family:monospace;font-size:13px;background:#0d1629;border:1px solid #1e2d47;font-weight:700;color:#475569;"></th><th style="padding:7px 16px;font-family:monospace;font-size:13px;background:#0d1629;border:1px solid #1e2d47;font-weight:700;color:#f59e0b;">F</th></tr></thead><tbody><tr><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#0f1f35;font-weight:700;"><span style="color:#10b981;font-weight:700;">1</span></td></tr><tr><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#0f1f35;font-weight:700;"><span style="color:#10b981;font-weight:700;">1</span></td></tr><tr><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"></td><td style="padding:7px 20px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#0f1f35;font-weight:700;"><span style="color:#10b981;font-weight:700;">1</span></td></tr></tbody></table></div><div style="margin-top:12px;padding:8px 14px;background:#0f1f12;border-radius:6px;font-family:monospace;font-size:13px;color:#10b981;">✅ Ответ: wxyz</div></div></div>

# %%
# Задание 203 — ищем строки где F = 1
print("x y z w")
for x in 0, 1:
    for y in 0, 1:
        for z in 0, 1:
            for w in 0, 1:
                f = (y <= x) and not z and w
                if f:   # здесь if f, а не if not f!
                    print(x, y, z, w)

# %% [markdown]
# <div style="display:inline-flex;align-items:flex-start;gap:10px;margin:4px 0;background:#1a2235;border:1px solid #1e2d47;border-left:3px solid #f59e0b;border-radius:6px;padding:8px 12px;max-width:fit-content;"><div style="background:#f59e0b;color:#000;font-weight:800;font-size:11px;border-radius:4px;padding:2px 8px;white-space:nowrap;flex-shrink:0;font-family:sans-serif;margin-top:1px;">шаг 1</div><div style="font-family:monospace;font-size:13px;color:#94a3b8;line-height:1.7;">Программа выводит 3 строки<br><span style="color:#94a3b8;font-size:11px;font-style:italic;"><code>0 0 0 1</code> &nbsp; <code>1 0 0 1</code> &nbsp; <code>1 1 0 1</code></span></div></div><br>
# <div style="display:inline-flex;align-items:flex-start;gap:10px;margin:4px 0;background:#1a2235;border:1px solid #1e2d47;border-left:3px solid #f59e0b;border-radius:6px;padding:8px 12px;max-width:fit-content;"><div style="background:#f59e0b;color:#000;font-weight:800;font-size:11px;border-radius:4px;padding:2px 8px;white-space:nowrap;flex-shrink:0;font-family:sans-serif;margin-top:1px;">шаг 2</div><div style="font-family:monospace;font-size:13px;color:#94a3b8;line-height:1.7;">Сопоставляем с таблицей из условия<br><span style="color:#94a3b8;font-size:11px;font-style:italic;">1-й столбец (1,1,1) — одни единицы → <b style="color:#10b981;">w</b><br>3-й столбец (0,0,0) — одни нули → <b style="color:#10b981;">z</b><br>4-й столбец — пустой (Миша не заполнил) → <b style="color:#10b981;">z</b>... нет, пустой → это переменная, значения которой не известны → наш z=(0,0,0), значит пустой столбец = <b style="color:#10b981;">z</b><br>💬 Остались 2-й и 4-й столбцы: x=(0,1,1) совпадает со 2-м столбцом (0,1,1) ✓<br>→ 2-й = <b style="color:#10b981;">x</b>, 4-й = <b style="color:#10b981;">y</b></span></div></div><br>
# <div style="margin-top:8px;"><table style="border-collapse:collapse;margin:8px 0;"><thead><tr><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">w</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">x</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">z</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">y</th></tr></thead><tbody><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td></tr></tbody></table></div>

# %% [markdown]
# <hr style="border:none;border-top:1px solid #1e2d47;margin:28px 0;">
# ## Шпаргалка
#
# ### Все операции в одной таблице
#
# <table style="border-collapse:collapse;margin:8px 0;"><thead><tr><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">A</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">B</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">¬A</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">A∧B</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">A∨B</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">A→B</th><th style="padding:7px 16px;font-family:monospace;font-size:13px;color:#94a3b8;background:#0d1629;border:1px solid #1e2d47;font-weight:600;">A≡B</th></tr></thead><tbody><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td></tr><tr><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#ef4444;font-weight:700;">0</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td><td style="padding:6px 16px;font-family:monospace;font-size:14px;text-align:center;border:1px solid #1e2d47;background:#1a2235;"><span style="color:#10b981;font-weight:700;">1</span></td></tr></tbody></table>
#
# <div style="background:#0d1f12;border-left:3px solid #10b981;border-radius:0 6px 6px 0;padding:12px 18px;margin:12px 0;font-size:14px;color:#94a3b8;font-family:sans-serif;">Импликация A→B ложна <b>только</b> при A=<span style="color:#ef4444;">1</span>, B=<span style="color:#ef4444;">0</span></div>
#
# ### Алгоритм сопоставления столбцов
#
# 1. **Столбец из одних нулей** → переменная, которая всегда 0
# 2. **Столбец из одних единиц** → переменная, которая всегда 1
# 3. **Паттерн импликации** A→B: строки (0,0), (0,1), (1,1) — но не (1,0)
#
# ### Итоговые ответы
#
# | Задание | Функция | Метод | Ответ |
# |:---:|:---|:---:|:---:|
# | 200 | (z → ¬(y → x)) ∨ w | Ручной | **zyxw** |
# | 201 | ¬(x → z) ∨ (y ≡ w) ∨ y | Ручной | **zxyw** |
# | 202 | ¬(x → w) ∨ (y → z) ∨ ¬y | Перебор | **yxwz** |
# | 203 | (y → x) ∧ ¬z ∧ w | Перебор | **wxyz** |
